# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone

# %%
import requests


url = "https://aerodatabox.p.rapidapi.com/airports/search/location"

querystring = {"lat":"52.31","lon":"13.24","radiusKm":"50","limit":"16","withFlightInfoOnly":"true"}

headers = {
	"x-rapidapi-key": "687292277emsh6620811a3972b04p1a4ee9jsn8c02f9bc139b",
	"x-rapidapi-host": "aerodatabox.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"searchBy":{"lat":52.31,"lon":13.24},"count":2,"items":[{"icao":"EDDB","iata":"BER","name":"Berlin Brandenburg","shortName":"Brandenburg","municipalityName":"Berlin","location":{"lat":52.35139,"lon":13.493889},"countryCode":"DE","timeZone":"Europe/Berlin"},{"icao":"EDDT","iata":"TXL","name":"Berlin -Tegel","shortName":"-Tegel","municipalityName":"Berlin","location":{"lat":52.5597,"lon":13.287699},"countryCode":"DE","timeZone":"Europe/Berlin"}]}

# %% [markdown]
# Let's view the response as `.json()` instead of `.text` so that it's easier to read

# %%
response.json()
# Out:
# {'searchBy': {'lat': 52.31, 'lon': 13.24},
#  'count': 2,
#  'items': [{'icao': 'EDDB',
#    'iata': 'BER',
#    'name': 'Berlin Brandenburg',
#    'shortName': 'Brandenburg',
#    'municipalityName': 'Berlin',
#    'location': {'lat': 52.35139, 'lon': 13.493889},
#    'countryCode': 'DE',
#    'timeZone': 'Europe/Berlin'},
#   {'icao': 'EDDT',
#    'iata': 'TXL',
#    'name': 'Berlin -Tegel',
#    'shortName': '-Tegel',
#    'municipalityName': 'Berlin',
#    'location': {'lat': 52.5597, 'lon': 13.287699},
#    'countryCode': 'DE',
#    'timeZone': 'Europe/Berlin'}]}

# %% [markdown]
# We can now turn this into a dataframe using `.json_normalize()`

# %%
pd.json_normalize(response.json()['items'])
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
# 1  EDDT  TXL       Berlin -Tegel       -Tegel           Berlin          DE
#
#         timeZone  location.lat  location.lon
# 0  Europe/Berlin      52.35139     13.493889
# 1  Europe/Berlin      52.55970     13.287699

# %% [markdown]
# Let's now use this for the latitude and longitude of multiple cities

# %%
def get_airports(latitudes, longitudes):
  # API headers
  headers = {
      "X-RapidAPI-Key": "687292277emsh6620811a3972b04p1a4ee9jsn8c02f9bc139b",
      "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
  }

  querystring = {"withFlightInfoOnly": "true"}

  # DataFrame to store results
  all_airports = []

  for lat, lon in zip(latitudes, longitudes):
    # Construct the URL with the latitude and longitude
    url = f"https://aerodatabox.p.rapidapi.com/airports/search/location/{lat}/{lon}/km/50/16"

    # Make the API request
    response = requests.get(url, headers=headers, params=querystring)

    if response.status_code == 200:
      data = response.json()
      airports = pd.json_normalize(data.get('items', []))
      all_airports.append(airports)

  return pd.concat(all_airports, ignore_index=True)

# %%
# coordinates for Berlin, Paris, London
latitudes = [52.5200, 48.8567, 51.5072]
longitudes = [13.4050, 2.3522, -0.1275]

get_airports(latitudes, longitudes)
# Out:
#     icao iata                     name          shortName municipalityName  \
# 0   EDDT  TXL            Berlin -Tegel             -Tegel           Berlin
# 1   EDDB  BER       Berlin Brandenburg        Brandenburg           Berlin
# 2   LFPB  LBG        Paris -Le Bourget        -Le Bourget            Paris
# 3   LFPO  ORY              Paris -Orly              -Orly            Paris
# 4   LFPG  CDG  Paris Charles de Gaulle  Charles de Gaulle            Paris
# 5   EGLC  LCY              London City               City           London
# 6   EGLL  LHR          London Heathrow           Heathrow           London
# 7   EGKR  KRH        Redhill Aerodrome          Aerodrome          Redhill
# 8   EGKK  LGW           London Gatwick            Gatwick           London
# 9   EGGW  LTN             London Luton              Luton           London
# 10  EGSS  STN          London Stansted           Stansted           London
#
#    countryCode       timeZone  location.lat  location.lon
# 0           DE  Europe/Berlin      52.55970     13.287699
# 1           DE  Europe/Berlin      52.35139     13.493889
# 2           FR   Europe/Paris      48.96940      2.441390
# 3           FR   Europe/Paris      48.72530      2.359440
# 4           FR   Europe/Paris      49.01280      2.549999
# 5           GB  Europe/London      51.50530      0.055277
# 6           GB  Europe/London      51.47060     -0.461941
# 7           GB  Europe/London      51.21360     -0.138611
# 8           GB  Europe/London      51.14810     -0.190277
# 9           GB  Europe/London      51.87470     -0.368333
# 10          GB  Europe/London      51.88500      0.234999

# %% [markdown]
# # **Arrivals information**

# %%
import requests

url = "https://aerodatabox.p.rapidapi.com/flights/airports/icao/EDDB/2025-03-24T20:00/2025-03-24T22:00"

querystring = {"withLeg":"true",
               "direction":"Arrival",
               "withCancelled":"false",
               "withCodeshared":"true",
               "withCargo":"false",
               "withPrivate":"false"}

headers = {
	"x-rapidapi-key": "687292277emsh6620811a3972b04p1a4ee9jsn8c02f9bc139b",
	"x-rapidapi-host": "aerodatabox.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
flights_json = response.json()
print (flights_json)
# Out:
# {'arrivals': [{'departure': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga', 'timeZone': 'Europe/Riga'}, 'scheduledTime': {'utc': '2025-03-24 16:55Z', 'local': '2025-03-24 18:55+02:00'}, 'revisedTime': {'utc': '2025-03-24 16:55Z', 'local': '2025-03-24 18:55+02:00'}, 'runwayTime': {'utc': '2025-03-24 17:26Z', 'local': '2025-03-24 19:26+02:00'}, 'terminal': 'C', 'gate': 'C6', 'runway': '36', 'quality': ['Basic', 'Live']}, 'arrival': {'scheduledTime': {'utc': '2025-03-24 18:45Z', 'local': '2025-03-24 19:45+01:00'}, 'revisedTime': {'utc': '2025-03-24 19:01Z', 'local': '2025-03-24 20:01+01:00'}, 'terminal': '2', 'gate': 'Z36', 'baggageBelt': 'C1', 'quality': ['Basic', 'Live']}, 'number': 'FR 2637', 'callSign': 'RYR2637', 'status': 'Arrived', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'SP-RNH', 'modeS': '48C1A7', 'model': 'Boeing 737'}, 'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}}, {'departure': {'airport': {'icao': 'LFSB', 'iata': 'BSL', 'name': 'Bâle/Mulhouse', 'timeZone': 'Europe/Paris'}, 'scheduledTime': {'utc': '2025-03-24 18:00Z', 'local': '2025-03-24 19:00+01:00'}, 'revisedTime': {'utc': '2025-03-24 17:58Z', 'local': '2025-03-24 18:58+01:00'}, 'checkInDesk': '42-50', 'gate': '84', 'quality': ['Basic', 'Live']}, 'arrival': {'scheduledTime': {'utc': '2025-03-24 19:30Z', 'local': '2025-03-24 20:30+01:00'}, 'revisedTime': {'utc': '2025-03-24 19:04Z', 'local': '2025-03-24 20:04+01:00'}, 'runwayTime': {'utc': '2025-03-24 19:03Z', 'local': '2025-03-24 20:03+01:00'}, 'terminal': '1', 'gate': 'A31', 'baggageBelt': 'A4', 'runway': '07R', 'quality': ['Basic', 'Live']}, 'number': 'DS 1187', 'callSign': 'EZS23BQ', 'status': 'Arrived', 'codeshareStatus': 'IsCodeshared', 'isCargo': False, 'aircraft': {'reg': 'OE-ICF', 'modeS': '440019', 'model': 'Airbus A320'}, 'airline': {'name': 'Easyjet Switzerland', 'iata': 'DS', 'icao': 'EZS'}}, {'departure': {'airport': {'icao': 'LFSB', 'iata': 'BSL', 'name': 'Bâle/Mulhouse', 'timeZone': 'Europe/Paris'}, 'scheduledTime': {'utc': '2025-03-24 18:00Z', 'local': '2025-03-24 19:00+01:00'}, 'revisedTime': {'utc': '2025-03-24 17:58Z', 'local': '2025-03-24 18:58+01:00'}, 'checkInDesk': '42-50', 'gate': '84', 'quality': ['Basic', 'Live']}, 'arrival': {'scheduledTime': {'utc': '2025-03-24 19:30Z', 'local': '2025-03-24 20:30+01:00'}, 'revisedTime': {'utc': '2025-03-24 19:04Z', 'local': '2025-03-24 20:04+01:00'}, 'runwayTime': {'utc': '2025-03-24 19:03Z', 'local': '2025-03-24 20:03+01:00'}, 'terminal': '1', 'gate': 'A31', 'baggageBelt': 'A4', 'runway': '07R', 'quality': ['Basic', 'Live']}, 'number': 'U2 1187', 'callSign': 'EZS23BQ', 'status': 'Arrived', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'OE-ICF', 'modeS': '440019', 'model': 'Airbus A320'}, 'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}}, {'departure': {'airport': {'icao': 'ELLX', 'iata': 'LUX', 'name': 'Luxembourg', 'timeZone': 'Europe/Luxembourg'}, 'scheduledTime': {'utc': '2025-03-24 17:50Z', 'local': '2025-03-24 18:50+01:00'}, 'revisedTime': {'utc': '2025-03-24 17:47Z', 'local': '2025-03-24 18:47+01:00'}, 'runwayTime': {'utc': '2025-03-24 17:57Z', 'local': '2025-03-24 18:57+01:00'}, 'terminal': 'A', 'gate': 'B04', 'quality': ['Basic', 'Live']}, 'arrival': {'scheduledTime': {'utc': '2025-03-24 19:20Z', 'local': '2025-03-24 20:20+01:00'}, 'revisedTime': {'utc': '2025-03-24 19:07Z', 'local': '2025-03-24 20:07+01:00'}, 'runwayTime': {'utc': '2025-03-24 19:07Z', 'local': '2025-03-24 20:07+01:00'}, 'terminal': '1', 'gate': 'S01', 'baggageBelt': 'B1', 'runway': '07L', 'quality': ['Basic', 'Live']}, 'number': 'LG 9473', 'callSign': 'LGL9473', 'status': 'Arrived', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'LX-LQC', 'modeS': '4D00D7', 'model': 'De Havilland Canada DHC-8-400 Dash 8Q'}, 'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}}, {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich', 'timeZone': 'Europe ...

# %%
flights_json
# Out:
# {'arrivals': [{'departure': {'airport': {'icao': 'EVRA',
#      'iata': 'RIX',
#      'name': 'Riga',
#      'timeZone': 'Europe/Riga'},
#     'scheduledTime': {'utc': '2025-03-24 16:55Z',
#      'local': '2025-03-24 18:55+02:00'},
#     'revisedTime': {'utc': '2025-03-24 16:55Z',
#      'local': '2025-03-24 18:55+02:00'},
#     'runwayTime': {'utc': '2025-03-24 17:26Z',
#      'local': '2025-03-24 19:26+02:00'},
#     'terminal': 'C',
#     'gate': 'C6',
#     'runway': '36',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 18:45Z',
#      'local': '2025-03-24 19:45+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:01Z',
#      'local': '2025-03-24 20:01+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 2637',
#    'callSign': 'RYR2637',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SP-RNH', 'modeS': '48C1A7', 'model': 'Boeing 737'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2025-03-24 18:00Z',
#      'local': '2025-03-24 19:00+01:00'},
#     'revisedTime': {'utc': '2025-03-24 17:58Z',
#      'local': '2025-03-24 18:58+01:00'},
#     'checkInDesk': '42-50',
#     'gate': '84',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:30Z',
#      'local': '2025-03-24 20:30+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:04Z',
#      'local': '2025-03-24 20:04+01:00'},
#     'runwayTime': {'utc': '2025-03-24 19:03Z',
#      'local': '2025-03-24 20:03+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A4',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 1187',
#    'callSign': 'EZS23BQ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICF', 'modeS': '440019', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2025-03-24 18:00Z',
#      'local': '2025-03-24 19:00+01:00'},
#     'revisedTime': {'utc': '2025-03-24 17:58Z',
#      'local': '2025-03-24 18:58+01:00'},
#     'checkInDesk': '42-50',
#     'gate': '84',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:30Z',
#      'local': '2025-03-24 20:30+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:04Z',
#      'local': '2025-03-24 20:04+01:00'},
#     'runwayTime': {'utc': '2025-03-24 19:03Z',
#      'local': '2025-03-24 20:03+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A4',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'DS 1187',
#    'callSign': 'EZS23BQ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICF', 'modeS': '440019', 'model': 'Airbus A320'},
#    'airline': {'name': 'Easyjet Switzerland', 'iata': 'DS', 'icao': 'EZS'}},
#   {'departure': {'airport': {'icao': 'ELLX',
#      'iata': 'LUX',
#      'name': 'Luxembourg',
#      'timeZone': 'Europe/Luxembourg'},
#     'scheduledTime': {'utc': '2025-03-24 17:50Z',
#      'local': '2025-03-24 18:50+01:00'},
#     'revisedTime': {'utc': '2025-03-24 17:47Z',
#      'local': '2025-03-24 18:47+01:00'},
#     'runwayTime': {'utc': '2025-03-24 17:57Z',
#      'local': '2025-03-24 18:57+01:00'},
#     'terminal': 'A',
#     'gate': 'B04',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:20Z',
#      'local': '2025-03-24 20:20+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:07Z',
#      'local': '2025-03-24 20:07+01:00'},
#     'runwayTime': {'utc': '2025-03-24 19:07Z',
#      'local': '2025-03-24 20:07+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'runway': '07L',
#     'quality': ['Basic', 'Live']},
#    'number': 'LG 9473',
#    'callSign': 'LGL9473',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LX-LQC',
#     'modeS': '4D00D7',
#     'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#    'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}},
#   {'departure': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2025-03-24 18:05Z',
#      'local': '2025-03-24 19:05+01:00'},
#     'revisedTime': {'utc': '2025-03-24 18:05Z',
#      'local': '2025-03-24 19:05+01:00'},
#     'runwayTime': {'utc': '2025-03-24 18:22Z',
#      'local': '2025-03-24 19:22+01:00'},
#     'terminal': '2',
#     'runway': '26R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:15Z',
#      'local': '2025-03-24 20:15+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:12Z',
#      'local': '2025-03-24 20:12+01:00'},
#     'terminal': '1',
#     'gate': 'A01',
#     'baggageBelt': 'A3',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'VL 1954',
#    'callSign': 'LHX1954',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIJN',
#     'modeS': '3C654E',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'VL', 'iata': 'VL', 'icao': 'LHX'}},
#   {'departure': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2025-03-24 16:40Z',
#      'local': '2025-03-24 17:40+01:00'},
#     'revisedTime': {'utc': '2025-03-24 16:58Z',
#      'local': '2025-03-24 17:58+01:00'},
#     'runwayTime': {'utc': '2025-03-24 17:09Z',
#      'local': '2025-03-24 18:09+01:00'},
#     'terminal': '1',
#     'checkInDesk': '501-514',
#     'gate': 'B39',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:20Z',
#      'local': '2025-03-24 20:20+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:21Z',
#      'local': '2025-03-24 20:21+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'VY 1886',
#    'callSign': 'VLG877W',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-MGY', 'modeS': '344699', 'model': 'Airbus A321'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}},
#   {'departure': {'airport': {'icao': 'LGTS',
#      'iata': 'SKG',
#      'name': 'Thessaloniki',
#      'timeZone': 'Europe/Athens'},
#     'scheduledTime': {'utc': '2025-03-24 16:45Z',
#      'local': '2025-03-24 18:45+02:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:20Z',
#      'local': '2025-03-24 20:20+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:23Z',
#      'local': '2025-03-24 20:23+01:00'},
#     'terminal': '2',
#     'gate': 'Z30',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1147',
#    'callSign': 'RYR8ZH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-IGY',
#     'modeS': '4CADE4',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EGKK',
#      'iata': 'LGW',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2025-03-24 17:50Z',
#      'local': '2025-03-24 17:50+00:00'},
#     'revisedTime': {'utc': '2025-03-24 17:52Z',
#      'local': '2025-03-24 17:52+00:00'},
#     'terminal': 'N',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:40Z',
#      'local': '2025-03-24 20:40+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:25Z',
#      'local': '2025-03-24 20:25+01:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 8625',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EZDH', 'modeS': '405636', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LIPE',
#      'iata': 'BLQ',
#      'name': 'Bologna',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2025-03-24 17:35Z',
#      'local': '2025-03-24 18:35+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:20Z',
#      'local': '2025-03-24 20:20+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:26Z',
#      'local': '2025-03-24 20:26+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 137',
#    'callSign': 'RYR92EB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-HAX', 'modeS': '4CA9A9', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LEMG',
#      'iata': 'AGP',
#      'name': 'Málaga',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2025-03-24 16:15Z',
#      'local': '2025-03-24 17:15+01:00'},
#     'revisedTime': {'utc': '2025-03-24 16:11Z',
#      'local': '2025-03-24 17:11+01:00'},
#     'terminal': 'PAX',
#     'checkInDesk': '258-260',
#     'gate': 'D45',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:55Z',
#      'local': '2025-03-24 20:55+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:28Z',
#      'local': '2025-03-24 20:28+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5106',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDD', 'modeS': '440CCC', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LEMG',
#      'iata': 'AGP',
#      'name': 'Málaga',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2025-03-24 16:15Z',
#      'local': '2025-03-24 17:15+01:00'},
#     'revisedTime': {'utc': '2025-03-24 16:11Z',
#      'local': '2025-03-24 17:11+01:00'},
#     'terminal': 'PAX',
#     'checkInDesk': '258-260',
#     'gate': 'D45',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:55Z',
#      'local': '2025-03-24 20:55+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:28Z',
#      'local': '2025-03-24 20:28+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5106',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDD', 'modeS': '440CCC', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2025-03-24 17:40Z',
#      'local': '2025-03-24 17:40+00:00'},
#     'revisedTime': {'utc': '2025-03-24 18:00Z',
#      'local': '2025-03-24 18:00+00:00'},
#     'runwayTime': {'utc': '2025-03-24 18:01Z',
#      'local': '2025-03-24 18:01+00:00'},
#     'terminal': '5',
#     'checkInDesk': 'D',
#     'runway': '27R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:35Z',
#      'local': '2025-03-24 20:35+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:30Z',
#      'local': '2025-03-24 20:30+01:00'},
#     'terminal': '1',
#     'gate': 'X10',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 980',
#    'callSign': 'BAW980',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-TTND',
#     'modeS': '407534',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'LIML',
#      'iata': 'LIN',
#      'name': 'Milan',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2025-03-24 18:15Z',
#      'local': '2025-03-24 19:15+01:00'},
#     'revisedTime': {'utc': '2025-03-24 18:19Z',
#      'local': '2025-03-24 19:19+01:00'},
#     'runwayTime': {'utc': '2025-03-24 18:19Z',
#      'local': '2025-03-24 19:19+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:55Z',
#      'local': '2025-03-24 20:55+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:40Z',
#      'local': '2025-03-24 20:40+01:00'},
#     'runwayTime': {'utc': '2025-03-24 19:39Z',
#      'local': '2025-03-24 20:39+01:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A3',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5066',
#    'callSign': 'EJU82AX',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LKO', 'modeS': '44009E', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LIML',
#      'iata': 'LIN',
#      'name': 'Milan',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2025-03-24 18:15Z',
#      'local': '2025-03-24 19:15+01:00'},
#     'revisedTime': {'utc': '2025-03-24 18:19Z',
#      'local': '2025-03-24 19:19+01:00'},
#     'runwayTime': {'utc': '2025-03-24 18:19Z',
#      'local': '2025-03-24 19:19+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:55Z',
#      'local': '2025-03-24 20:55+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:40Z',
#      'local': '2025-03-24 20:40+01:00'},
#     'runwayTime': {'utc': '2025-03-24 19:39Z',
#      'local': '2025-03-24 20:39+01:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A3',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5066',
#    'callSign': 'EJU82AX',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LKO', 'modeS': '44009E', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2025-03-24 18:45Z',
#      'local': '2025-03-24 19:45+01:00'},
#     'revisedTime': {'utc': '2025-03-24 18:45Z',
#      'local': '2025-03-24 19:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A18',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:55Z',
#      'local': '2025-03-24 20:55+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:41Z',
#      'local': '2025-03-24 20:41+01:00'},
#     'runwayTime': {'utc': '2025-03-24 19:41Z',
#      'local': '2025-03-24 20:41+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B4',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 200',
#    'callSign': 'DLH4LV',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISG', 'modeS': '3C6667', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EPWA',
#      'iata': 'WAW',
#      'name': 'Warsaw',
#      'timeZone': 'Europe/Warsaw'},
#     'scheduledTime': {'utc': '2025-03-24 18:40Z',
#      'local': '2025-03-24 19:40+01:00'},
#     'revisedTime': {'utc': '2025-03-24 18:40Z',
#      'local': '2025-03-24 19:40+01:00'},
#     'runwayTime': {'utc': '2025-03-24 18:48Z',
#      'local': '2025-03-24 19:48+01:00'},
#     'terminal': 'E-D',
#     'checkInDesk': '241-280',
#     'gate': '23',
#     'runway': '29',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:00Z',
#      'local': '2025-03-24 21:00+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:43Z',
#      'local': '2025-03-24 20:43+01:00'},
#     'runwayTime': {'utc': '2025-03-24 19:42Z',
#      'local': '2025-03-24 20:42+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LO 391',
#    'callSign': 'LOT7AN',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SP-LIN', 'modeS': '48AD0D', 'model': 'Embraer 175'},
#    'airline': {'name': 'LOT - Polish', 'iata': 'LO', 'icao': 'LOT'}},
#   {'departure': {'airport': {'icao': 'EGSS',
#      'iata': 'STN',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2025-03-24 18:00Z',
#      'local': '2025-03-24 18:00+00:00'},
#     'revisedTime': {'utc': '2025-03-24 18:09Z',
#      'local': '2025-03-24 18:09+00:00'},
#     'runwayTime': {'utc': '2025-03-24 18:29Z',
#      'local': '2025-03-24 18:29+00:00'},
#     'terminal': '1',
#     'gate': '45',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:40Z',
#      'local': '2025-03-24 20:40+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:52Z',
#      'local': '2025-03-24 20:52+01:00'},
#     'terminal': '2',
#     'gate': 'Z40',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 2788',
#    'callSign': 'RYR12RT',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VUT', 'modeS': '4D236A', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LIME',
#      'iata': 'BGY',
#      'name': 'Bergamo',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2025-03-24 18:25Z',
#      'local': '2025-03-24 19:25+01:00'},
#     'revisedTime': {'utc': '2025-03-24 18:41Z',
#      'local': '2025-03-24 19:41+01:00'},
#     'runwayTime': {'utc': '2025-03-24 18:41Z',
#      'local': '2025-03-24 19:41+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:05Z',
#      'local': '2025-03-24 21:05+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:54Z',
#      'local': '2025-03-24 20:54+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3401',
#    'callSign': 'RYR6DZ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-HMZ',
#     'modeS': '4CAC86',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EGCC',
#      'iata': 'MAN',
#      'name': 'Manchester',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2025-03-24 18:25Z',
#      'local': '2025-03-24 18:25+00:00'},
#     'revisedTime': {'utc': '2025-03-24 18:20Z',
#      'local': '2025-03-24 18:20+00:00'},
#     'runwayTime': {'utc': '2025-03-24 18:30Z',
#      'local': '2025-03-24 18:30+00:00'},
#     'terminal': '3',
#     'gate': '46',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:20Z',
#      'local': '2025-03-24 21:20+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:00Z',
#      'local': '2025-03-24 21:00+01:00'},
#     'terminal': '2',
#     'gate': 'Z44',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1155',
#    'callSign': 'RYR44XK',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-DCR', 'modeS': '4CA251', 'model': 'Boeing 737'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EGLC',
#      'iata': 'LCY',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2025-03-24 18:30Z',
#      'local': '2025-03-24 18:30+00:00'},
#     'revisedTime': {'utc': '2025-03-24 18:30Z',
#      'local': '2025-03-24 18:30+00:00'},
#     'runwayTime': {'utc': '2025-03-24 18:37Z',
#      'local': '2025-03-24 18:37+00:00'},
#     'gate': '7',
#     'runway': '27',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:10Z',
#      'local': '2025-03-24 21:10+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:03Z',
#      'local': '2025-03-24 21:03+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 8495',
#    'callSign': 'BAW8495',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-LCYZ', 'modeS': '4075A2', 'model': 'Embraer 190'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'OLBA',
#      'iata': 'BEY',
#      'name': 'Beirut',
#      'timeZone': 'Asia/Beirut'},
#     'scheduledTime': {'utc': '2025-03-24 15:15Z',
#      'local': '2025-03-24 17:15+02:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:35Z',
#      'local': '2025-03-24 20:35+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:07Z',
#      'local': '2025-03-24 21:07+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8981',
#    'callSign': 'EWG8981',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2025-03-24 18:35Z',
#      'local': '2025-03-24 19:35+01:00'},
#     'revisedTime': {'utc': '2025-03-24 18:51Z',
#      'local': '2025-03-24 19:51+01:00'},
#     'runwayTime': {'utc': '2025-03-24 19:10Z',
#      'local': '2025-03-24 20:10+01:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'gate': 'B3',
#     'runway': '36L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 19:50Z',
#      'local': '2025-03-24 20:50+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:09Z',
#      'local': '2025-03-24 21:09+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1783',
#    'callSign': 'KLM67D',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-EZE', 'modeS': '484B32', 'model': 'Embraer 190'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2025-03-24 19:05Z',
#      'local': '2025-03-24 20:05+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:05Z',
#      'local': '2025-03-24 20:05+01:00'},
#     'runwayTime': {'utc': '2025-03-24 19:11Z',
#      'local': '2025-03-24 20:11+01:00'},
#     'checkInDesk': '2(5)',
#     'gate': 'A72',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:45Z',
#      'local': '2025-03-24 21:45+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:14Z',
#      'local': '2025-03-24 21:14+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8763',
#    'callSign': 'EWG30A',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWJ', 'modeS': '3C56EA', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2025-03-24 17:45Z',
#      'local': '2025-03-24 18:45+01:00'},
#     'revisedTime': {'utc': '2025-03-24 17:46Z',
#      'local': '2025-03-24 18:46+01:00'},
#     'runwayTime': {'utc': '2025-03-24 18:09Z',
#      'local': '2025-03-24 19:09+01:00'},
#     'terminal': '2',
#     'checkInDesk': 'B60-B67',
#     'gate': 'U34',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:30Z',
#      'local': '2025-03-24 21:30+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:17Z',
#      'local': '2025-03-24 21:17+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 149',
#    'callSign': 'RYR218J',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-ENA', 'modeS': '4CA88C', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LHBP',
#      'iata': 'BUD',
#      'name': 'Budapest',
#      'timeZone': 'Europe/Budapest'},
#     'scheduledTime': {'utc': '2025-03-24 18:50Z',
#      'local': '2025-03-24 19:50+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:12Z',
#      'local': '2025-03-24 20:12+01:00'},
#     'runwayTime': {'utc': '2025-03-24 19:13Z',
#      'local': '2025-03-24 20:13+01:00'},
#     'terminal': '2B',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:20Z',
#      'local': '2025-03-24 21:20+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:19Z',
#      'local': '2025-03-24 21:19+01:00'},
#     'runwayTime': {'utc': '2025-03-24 20:20Z',
#      'local': '2025-03-24 21:20+01:00'},
#     'terminal': '2',
#     'gate': 'Z29',
#     'baggageBelt': 'C3',
#     'runway': '07L',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 207',
#    'callSign': 'RYR207',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SP-RKC', 'modeS': '48C122', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2025-03-24 19:10Z',
#      'local': '2025-03-24 20:10+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:00Z',
#      'local': '2025-03-24 20:00+01:00'},
#     'terminal': '3',
#     'checkInDesk': '27',
#     'gate': 'M1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:30Z',
#      'local': '2025-03-24 21:30+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:21Z',
#      'local': '2025-03-24 21:21+01:00'},
#     'runwayTime': {'utc': '2025-03-24 20:21Z',
#      'local': '2025-03-24 21:21+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A1',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5286',
#    'callSign': 'EJU37LH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQN', 'modeS': '440170', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2025-03-24 19:10Z',
#      'local': '2025-03-24 20:10+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:00Z',
#      'local': '2025-03-24 20:00+01:00'},
#     'terminal': '3',
#     'checkInDesk': '27',
#     'gate': 'M1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:30Z',
#      'local': '2025-03-24 21:30+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:21Z',
#      'local': '2025-03-24 21:21+01:00'},
#     'runwayTime': {'utc': '2025-03-24 20:21Z',
#      'local': '2025-03-24 21:21+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A1',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5286',
#    'callSign': 'EJU37LH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQN', 'modeS': '440170', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LPPT',
#      'iata': 'LIS',
#      'name': 'Lisbon',
#      'timeZone': 'Europe/Lisbon'},
#     'scheduledTime': {'utc': '2025-03-24 17:05Z',
#      'local': '2025-03-24 17:05+00:00'},
#     'revisedTime': {'utc': '2025-03-24 17:13Z',
#      'local': '2025-03-24 17:13+00:00'},
#     'runwayTime': {'utc': '2025-03-24 17:14Z',
#      'local': '2025-03-24 17:14+00:00'},
#     'terminal': '2',
#     'runway': '03',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:30Z',
#      'local': '2025-03-24 21:30+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:23Z',
#      'local': '2025-03-24 21:23+01:00'},
#     'runwayTime': {'utc': '2025-03-24 20:24Z',
#      'local': '2025-03-24 21:24+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C3',
#     'runway': '07L',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1143',
#    'callSign': 'RYR38GP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VUW', 'modeS': '4D2384', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EIDW',
#      'iata': 'DUB',
#      'name': 'Dublin',
#      'timeZone': 'Europe/Dublin'},
#     'scheduledTime': {'utc': '2025-03-24 18:20Z',
#      'local': '2025-03-24 18:20+00:00'},
#     'revisedTime': {'utc': '2025-03-24 18:20Z',
#      'local': '2025-03-24 18:20+00:00'},
#     'runwayTime': {'utc': '2025-03-24 18:35Z',
#      'local': '2025-03-24 18:35+00:00'},
#     'terminal': '1',
#     'checkInDesk': '1204-1319',
#     'gate': '111',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:30Z',
#      'local': '2025-03-24 21:30+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:27Z',
#      'local': '2025-03-24 21:27+01:00'},
#     'runwayTime': {'utc': '2025-03-24 20:27Z',
#      'local': '2025-03-24 21:27+01:00'},
#     'terminal': '2',
#     'gate': 'Z42',
#     'baggageBelt': 'C2',
#     'runway': '07L',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 5418',
#    'callSign': 'RYR6NF',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-EFI', 'modeS': '4CA764', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'UDYZ',
#      'iata': 'EVN',
#      'name': 'Yerevan',
#      'timeZone': 'Asia/Yerevan'},
#     'scheduledTime': {'utc': '2025-03-24 16:10Z',
#      'local': '2025-03-24 20:10+04:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:35Z',
#      'local': '2025-03-24 21:35+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:35Z',
#      'local': '2025-03-24 21:35+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8995',
#    'callSign': 'EWG2M',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENG',
#     'modeS': '3C55C7',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LTFM',
#      'iata': 'IST',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2025-03-24 17:40Z',
#      'local': '2025-03-24 20:40+03:00'},
#     'revisedTime': {'utc': '2025-03-24 17:50Z',
#      'local': '2025-03-24 20:50+03:00'},
#     'checkInDesk': 'E-F',
#     'gate': 'F13B',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:40Z',
#      'local': '2025-03-24 21:40+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:37Z',
#      'local': '2025-03-24 21:37+01:00'},
#     'terminal': '1',
#     'gate': 'Y03',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 1727',
#    'callSign': 'THY9YK',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-JTA', 'modeS': '4BAA81', 'model': 'Airbus A321'},
#    'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#   {'departure': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2025-03-24 18:55Z',
#      'local': '2025-03-24 18:55+00:00'},
#     'revisedTime': {'utc': '2025-03-24 19:12Z',
#      'local': '2025-03-24 19:12+00:00'},
#     'runwayTime': {'utc': '2025-03-24 19:13Z',
#      'local': '2025-03-24 19:13+00:00'},
#     'terminal': '5',
#     'checkInDesk': 'D',
#     'runway': '27R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:55Z',
#      'local': '2025-03-24 21:55+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:42Z',
#      'local': '2025-03-24 21:42+01:00'},
#     'terminal': '1',
#     'gate': 'X19',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 988',
#    'callSign': 'BAW988G',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EUUT', 'modeS': '401240', 'model': 'Airbus A320'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2025-03-24 19:40Z',
#      'local': '2025-03-24 20:40+01:00'},
#     'revisedTime': {'utc': '2025-03-24 19:44Z',
#      'local': '2025-03-24 20:44+01:00'},
#     'runwayTime': {'utc': '2025-03-24 19:57Z',
#      'local': '2025-03-24 20:57+01:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'gate': 'D59',
#     'runway': '09',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-03-24 20:55Z',
#      'local': '2025-03-24 21:55+01:00'},
#     'revisedTime': {'utc': '2025-03-24 20:50Z',
#      'local': '2025-03-24 21:50+01:00'},
#     'terminal': '1',
#     'gate': 'A07',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1785',
#    'callSign': 'KLM27F',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-AXC',
#     'modeS': '486741',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}}]}

# %%
flights_json.keys()
# Out:
# dict_keys(['arrivals'])

# %%
flights_json["arrivals"][0]
# Out:
# {'departure': {'airport': {'icao': 'EVRA',
#    'iata': 'RIX',
#    'name': 'Riga',
#    'timeZone': 'Europe/Riga'},
#   'scheduledTime': {'utc': '2025-03-24 16:55Z',
#    'local': '2025-03-24 18:55+02:00'},
#   'revisedTime': {'utc': '2025-03-24 16:55Z',
#    'local': '2025-03-24 18:55+02:00'},
#   'runwayTime': {'utc': '2025-03-24 17:26Z',
#    'local': '2025-03-24 19:26+02:00'},
#   'terminal': 'C',
#   'gate': 'C6',
#   'runway': '36',
#   'quality': ['Basic', 'Live']},
#  'arrival': {'scheduledTime': {'utc': '2025-03-24 18:45Z',
#    'local': '2025-03-24 19:45+01:00'},
#   'revisedTime': {'utc': '2025-03-24 19:01Z',
#    'local': '2025-03-24 20:01+01:00'},
#   'terminal': '2',
#   'gate': 'Z36',
#   'baggageBelt': 'C1',
#   'quality': ['Basic', 'Live']},
#  'number': 'FR 2637',
#  'callSign': 'RYR2637',
#  'status': 'Arrived',
#  'codeshareStatus': 'IsOperator',
#  'isCargo': False,
#  'aircraft': {'reg': 'SP-RNH', 'modeS': '48C1A7', 'model': 'Boeing 737'},
#  'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}}

# %%
flights_json["arrivals"][0].keys()
# Out:
# dict_keys(['departure', 'arrival', 'number', 'callSign', 'status', 'codeshareStatus', 'isCargo', 'aircraft', 'airline'])

# %%
df= pd.json_normalize(flights_json["arrivals"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   number                         33 non-null     object
#  1   callSign                       30 non-null     object
#  2   status                         33 non-null     object
#  3   codeshareStatus                33 non-null     object
#  4   isCargo                        33 non-null     bool
#  5   departure.airport.icao         33 non-null     object
#  6   departure.airport.iata         33 non-null     object
#  7   departure.airport.name         33 non-null     object
#  8   departure.airport.timeZone     33 non-null     object
#  9   departure.scheduledTime.utc    33 non-null     object
#  10  departure.scheduledTime.local  33 non-null     object
#  11  departure.revisedTime.utc      29 non-null     object
#  12  departure.revisedTime.local    29 non-null     object
#  13  departure.runwayTime.utc       20 non-null     object
#  14  departure.runwayTime.local     20 non-null     object
#  15  departure.terminal             21 non-null     object
#  16  departure.gate                 20 non-null     object
#  17  departure.runway               11 non-null     object
#  18  departure.quality              33 non-null     object
#  19  arrival.scheduledTime.utc      33 non-null     object
#  20  arrival.scheduledTime.local    33 non-null     object
#  21  arrival.revisedTime.utc        33 non-null     object
#  22  arrival.revisedTime.local      33 non-null     object
#  23  arrival.terminal               33 non-null     object
#  24  arrival.gate                   33 non-null     object
#  25  arrival.baggageBelt            33 non-null     object
#  26  arrival.quality                33 non-null     object
#  27  aircraft.reg                   33 non-null     object
#  28  aircraft.modeS                 33 non-null     object
#  29  aircraft.model                 33 non-null     object
#  30  airline.name                   33 non-null     object
#  31  airline.iata                   33 non-null     object
#  32  airline.icao                   33 non-null     object
#  33  departure.checkInDesk          17 non-null     object
#  34  arrival.runwayTime.utc         12 non-null     object
#  35  arrival.runwayTime.local       12 non-null     object
#  36  arrival.runway                 13 non-null     object
# dtypes: bool(1), object(36)
# memory usage: 9.4+ KB

# %%
columns_to_keep = [
    "number",
    "status",
    "departure.gate",
    "airline.icao",
    "departure.gate",
    "departure.gate"

]

# Filter the DataFrame
df_filtered = df[columns_to_keep]

# Optional: Preview the cleaned DataFrame
df_filtered
# Out:
#      number   status departure.gate airline.icao departure.gate departure.gate
# 0   FR 2637  Arrived             C6          RYR             C6             C6
# 1   U2 1187  Arrived             84          EZY             84             84
# 2   DS 1187  Arrived             84          EZS             84             84
# 3   LG 9473  Arrived            B04          LGL            B04            B04
# 4   VL 1954  Arrived            NaN          LHX            NaN            NaN
# 5   VY 1886  Arrived            B39          VLG            B39            B39
# 6   FR 1147  Arrived            NaN          RYR            NaN            NaN
# 7   U2 8625  Arrived            NaN          EZY            NaN            NaN
# 8    FR 137  Arrived            NaN          RYR            NaN            NaN
# 9   EC 5106  Arrived            D45          EJU            D45            D45
# 10  U2 5106  Arrived            D45          EZY            D45            D45
# 11   BA 980  Arrived            NaN          BAW            NaN            NaN
# 12  U2 5066  Arrived            NaN          EZY            NaN            NaN
# 13  EC 5066  Arrived            NaN          EJU            NaN            NaN
# 14   LH 200  Arrived            A18          DLH            A18            A18
# 15   LO 391  Arrived             23          LOT             23             23
# 16  FR 2788  Arrived             45          RYR             45             45
# 17  FR 3401  Arrived            NaN          RYR            NaN            NaN
# 18  FR 1155  Arrived             46          RYR             46             46
# 19  BA 8495  Arrived              7          BAW              7              7
# 20  EW 8981  Arrived            NaN          EWG            NaN            NaN
# 21  KL 1783  Arrived             B3          KLM             B3             B3
# 22  EW 8763  Arrived            A72          EWG            A72            A72
# 23   FR 149  Arrived            U34          RYR            U34            U34
# 24   FR 207  Arrived            NaN          RYR            NaN            NaN
# 25  U2 5286  Arrived             M1          EZY             M1             M1
# 26  EC 5286  Arrived             M1          EJU             M1             M1
# 27  FR 1143  Arrived            NaN          RYR            NaN            NaN
# 28  FR 5418  Arrived            111          RYR            111            111
# 29  EW 8995  Arrived            NaN          EWG            NaN            NaN
# 30  TK 1727  Arrived           F13B          THY           F13B           F13B
# 31   BA 988  Arrived            NaN          BAW            NaN            NaN
# 32  KL 1785  Arrived            D59          KLM            D59            D59

# %%
def flight_arrival_for_airports(airport_icaos):
    querystring = {
        "withLeg": "false",
        "direction": "Arrival",
        "withCancelled": "false",
        "withCodeshared": "true",
        "withCargo": "true",
        "withPrivate": "false",
        "withLocation": "false"
    }

    headers = {
        "x-rapidapi-key": "687292277emsh6620811a3972b04p1a4ee9jsn8c02f9bc139b",
        "x-rapidapi-host": "aerodatabox.p.rapidapi.com"
    }

    all_arrivals = []

    for icao in airport_icaos:
        url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/2025-03-24T20:00/2025-03-24T22:00"
        response = requests.get(url, headers=headers, params=querystring)

        if response.status_code == 200:
            data = response.json()
            arrivals = pd.json_normalize(data.get('arrivals', []))
            if not arrivals.empty:
                arrivals["airport_icao"] = icao  # Add source airport column
                all_arrivals.append(arrivals)
        else:
            print(f"Failed to get data for {icao}: {response.status_code}")

    # Concatenate all results into one DataFrame
    if all_arrivals:
        return pd.concat(all_arrivals, ignore_index=True)
    else:
        return pd.DataFrame()

# %%
airport_icaos = ['EDDB', 'EGKK']

flight_arrival_for_airports(airport_icaos)
# Out:
#      number callSign   status codeshareStatus  isCargo movement.airport.icao  \
# 0   FR 2637  RYR2637  Arrived      IsOperator    False                  EVRA
# 1   DS 1187  EZS23BQ  Arrived    IsCodeshared    False                  LFSB
# 2   U2 1187  EZS23BQ  Arrived      IsOperator    False                  LFSB
# 3   LG 9473  LGL9473  Arrived      IsOperator    False                  ELLX
# 4   VL 1954  LHX1954  Arrived      IsOperator    False                  EDDM
# ..      ...      ...      ...             ...      ...                   ...
# 69   BY 771   TOM771  Arrived      IsOperator    False                  HEGN
# 70  U2 8764  EZY78CZ  Arrived      IsOperator    False                  LMML
# 71  U2 8314  EZY98NA  Arrived      IsOperator    False                  LIMC
# 72  U2 8480  EZY73UW  Arrived      IsOperator    False                  LFSB
# 73  U2 6340  EZY58YT  Arrived      IsOperator    False                  LFRS
#
#    movement.airport.iata movement.airport.name movement.airport.timeZone  \
# 0                    RIX                  Riga               Europe/Riga
# 1                    BSL         Bâle/Mulhouse              Europe/Paris
# 2                    BSL         Bâle/Mulhouse              Europe/Paris
# 3                    LUX            Luxembourg         Europe/Luxembourg
# 4                    MUC                Munich             Europe/Berlin
# ..                   ...                   ...                       ...
# 69                   HRG              Hurghada              Africa/Cairo
# 70                   MLA                  Luqa              Europe/Malta
# 71                   MXP                 Milan               Europe/Rome
# 72                   BSL         Bâle/Mulhouse              Europe/Paris
# 73                   NTE                Nantes              Europe/Paris
#
#    movement.scheduledTime.utc  ... aircraft.reg aircraft.modeS  \
# 0           2025-03-24 18:45Z  ...       SP-RNH         48C1A7
# 1           2025-03-24 19:30Z  ...       OE-ICF         440019
# 2           2025-03-24 19:30Z  ...       OE-ICF         440019
# 3           2025-03-24 19:20Z  ...       LX-LQC         4D00D7
# 4           2025-03-24 19:15Z  ...       D-AIJN         3C654E
# ..                        ...  ...          ...            ...
# 69          2025-03-24 21:50Z  ...       G-TUMX         407E7B
# 70          2025-03-24 21:50Z  ...       G-UZMK         40812D
# 71          2025-03-24 21:50Z  ...       G-EZDV         405D0F
# 72          2025-03-24 21:55Z  ...       G-EJCA         407E5F
# 73          2025-03-24 21:55Z  ...       G-EJCF         407F65
#
#                            aircraft.model         airline.name airline.iata  \
# 0                              Boeing 737              Ryanair           FR
# 1                             Airbus A320  Easyjet Switzerland           DS
# 2                             Airbus A320              easyJet           U2
# 3   De Havilland Canada DHC-8-400 Dash 8Q               Luxair           LG
# 4                         Airbus A320 NEO                   VL           VL
# ..                                    ...                  ...          ...
# 69                       Boeing 737 MAX 8                  TUI           BY
# 70                        Airbus A321 NEO              easyJet           U2
# 71                            Airbus A319              easyJet           U2
# 72                            Airbus A320              easyJet           U2
# 73                            Airbus A320              easyJet           U2
#
#    airline.icao movement.runwayTime.utc movement.runwayTime.local  \
# 0           RYR                     NaN                       NaN
# 1           EZS       2025-03-24 19:03Z    2025-03-24 20:03+01:00
# 2           EZY       2025-03-24 19:03Z    2025-03-24 20:03+01:00
# 3           LGL       2025-03-24 19:07Z    2025-03-24 20:07+01:00
# 4           LHX                     NaN                       NaN
# ..          ...                     ...                       ...
# 69          TOM                     NaN                       NaN
# 70          EZY                     NaN                       NaN
# 71          EZY                     NaN                       NaN
# 72          EZY                     NaN                       NaN
# 73          EZY                     NaN                       NaN
#
#    movement.runway airport_icao
# 0              NaN         EDDB
# 1              07R         EDDB
# 2              07R         EDDB
# 3              07L         EDDB
# 4              07R         EDDB
# ..             ...          ...
# 69             NaN         EGKK
# 70             NaN         EGKK
# 71             26L         EGKK
# 72             NaN         EGKK
# 73             NaN         EGKK
#
# [74 rows x 27 columns]
